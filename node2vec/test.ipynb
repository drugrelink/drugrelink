# %%
import gzip
import pandas as pd
f = gzip.open('/home/lxu/Downloads/edges.sif.gz','rb')
df = pd.read_csv(f,sep='\t')
df.head()
# Out:
#         source metaedge                          target
# 0   Gene::9021     GpBP  Biological Process::GO:0071357
# 1  Gene::51676     GpBP  Biological Process::GO:0098780
# 2     Gene::19     GpBP  Biological Process::GO:0055088
# 3   Gene::3176     GpBP  Biological Process::GO:0010243
# 4   Gene::3039     GpBP  Biological Process::GO:0006898

# %%
import  bz2
f =  bz2.BZ2File('/home/lxu/Downloads/transformed-features(1).tsv.bz2','r'
                )
df = pd.read_csv(f,sep='\t',low_memory=False)
df.head()
# Out:
#   compound_id compound_name  disease_id         disease_name category  status  \
# 0     DB01048      Abacavir  DOID:10652  Alzheimer's disease      NaN       0
# 1     DB05812   Abiraterone  DOID:10652  Alzheimer's disease      NaN       0
# 2     DB00659   Acamprosate  DOID:10652  Alzheimer's disease      NaN       0
# 3     DB00284      Acarbose  DOID:10652  Alzheimer's disease      NaN       0
# 4     DB01193    Acebutolol  DOID:10652  Alzheimer's disease      NaN       0
#
#    prior_prob  prior_logit  degree_CbG  degree_CcSE  ...  dwpc_CuGaDuGaD  \
# 0    0.004753       -5.344     -0.2955       0.8146  ...         -0.5028
# 1    0.004753       -5.344      0.5495       0.5554  ...         -0.5028
# 2    0.004753       -5.344      0.9053       1.0220  ...         -0.5028
# 3    0.004753       -5.344      0.4328       0.3460  ...          0.4304
# 4    0.004753       -5.344      0.1403       0.7966  ...         -0.5028
#
# ...
